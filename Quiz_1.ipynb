# %%
[ (a,b) for a in range(3) for b in range(a) ]
# Out:
# [(1, 0), (2, 0), (2, 1)]

# %%
class Demo: 
   def __init__(self,d): 
      self.d=d 
   def print(self): 
      print(self.d)  

a = Demo('Hello') 
a.print()
# Out:
# Hello

# %%
L = ['a', 'b', 'c', 'd']
S = "".join(L)
print(S)
# Out:
# abcd

# %%
y = 8
z = lambda x : x * y
print (z(6))
# Out:
# 48

# %%
print(type(‘int’))
# Out:
#   Cell In[10], line 1
#     print(type(‘int’))
#                ^
# SyntaxError: invalid character '‘' (U+2018)

# %%
print(type(int))
# Out:
# <class 'type'>
